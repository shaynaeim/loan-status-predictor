# %%
import pandas as pd

# %%
data_info = pd.read_csv('../DATA/lending_club_info.csv', index_col='LoanStatNew')

# %%
print(data_info.loc['revol_util']['Description'])
# Out:
# Revolving line utilization rate, or the amount of credit the borrower is using relative to all available revolving credit.

# %%
def feat_info(col_name):
    print(data_info.loc[col_name]['Description'])

# %%
feat_info('mort_acc')
# Out:
# Number of mortgage accounts.

# %% [markdown]
# ## Loading the data and other imports

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %matplotlib inline

# %%
df = pd.read_csv('../DATA/lending_club_loan_two.csv')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 396030 entries, 0 to 396029
# Data columns (total 27 columns):
#  #   Column                Non-Null Count   Dtype
# ---  ------                --------------   -----
#  0   loan_amnt             396030 non-null  float64
#  1   term                  396030 non-null  object
#  2   int_rate              396030 non-null  float64
#  3   installment           396030 non-null  float64
#  4   grade                 396030 non-null  object
#  5   sub_grade             396030 non-null  object
#  6   emp_title             373103 non-null  object
#  7   emp_length            377729 non-null  object
#  8   home_ownership        396030 non-null  object
#  9   annual_inc            396030 non-null  float64
#  10  verification_status   396030 non-null  object
#  11  issue_d               396030 non-null  object
#  12  loan_status           396030 non-null  object
#  13  purpose               396030 non-null  object
# ...

# %% [markdown]
# ## Data Analysis: Underestand which variables are important, view summary statistics, and visualize the data

# %%
sns.countplot(x='loan_status',data=df)
# Out:
# <Axes: xlabel='loan_status', ylabel='count'>

# %%
plt.figure(figsize=(12,4))
sns.histplot(df['loan_amnt'], kde=False, bins=40)
plt.xlim(0,45000)
# Out:
# (0.0, 45000.0)

# %%
df_numeric = df.select_dtypes(include=['number'])
df_numeric.corr()
# Out:
#                       loan_amnt  int_rate  installment  annual_inc       dti  \
# loan_amnt              1.000000  0.168921     0.953929    0.336887  0.016636
# int_rate               0.168921  1.000000     0.162758   -0.056771  0.079038
# installment            0.953929  0.162758     1.000000    0.330381  0.015786
# annual_inc             0.336887 -0.056771     0.330381    1.000000 -0.081685
# dti                    0.016636  0.079038     0.015786   -0.081685  1.000000
# open_acc               0.198556  0.011649     0.188973    0.136150  0.136181
# pub_rec               -0.077779  0.060986    -0.067892   -0.013720 -0.017639
# revol_bal              0.328320 -0.011280     0.316455    0.299773  0.063571
# revol_util             0.099911  0.293659     0.123915    0.027871  0.088375
# total_acc              0.223886 -0.036404     0.202430    0.193023  0.102128
# mort_acc               0.222315 -0.082583     0.193694    0.236320 -0.025439
# ...

# %%
plt.figure(figsize=(25,12))
sns.heatmap(df_numeric.corr(), annot=True, cmap='viridis')
plt.ylim(10, 0)
# Out:
# (10.0, 0.0)

# %%
feat_info('installment')
# Out:
# The monthly payment owed by the borrower if the loan originates.

# %%
feat_info('loan_amnt')
# Out:
# The listed amount of the loan applied for by the borrower. If at some point in time, the credit department reduces the loan amount, then it will be reflected in this value.

# %%
sns.scatterplot(x='installment',y='loan_amnt',data=df,)
# Out:
# <Axes: xlabel='installment', ylabel='loan_amnt'>

# %%
sns.boxplot(x='loan_status',y='loan_amnt',data=df)
# Out:
# <Axes: xlabel='loan_status', ylabel='loan_amnt'>

# %%
df.groupby('loan_status')['loan_amnt'].describe()
# Out:
#                 count          mean          std     min     25%      50%  \
# loan_status
# Charged Off   77673.0  15126.300967  8505.090557  1000.0  8525.0  14000.0
# Fully Paid   318357.0  13866.878771  8302.319699   500.0  7500.0  12000.0
#
#                  75%      max
# loan_status
# Charged Off  20000.0  40000.0
# Fully Paid   19225.0  40000.0

# %%
sorted(df['grade'].unique())
# Out:
# ['A', 'B', 'C', 'D', 'E', 'F', 'G']

# %%
sorted(df['sub_grade'].unique())
# Out:
# ['A1',
#  'A2',
#  'A3',
#  'A4',
#  'A5',
#  'B1',
#  'B2',
#  'B3',
#  'B4',
#  'B5',
#  'C1',
#  'C2',
#  'C3',
#  'C4',
#  'C5',
#  'D1',
#  'D2',
#  'D3',
#  'D4',
#  'D5',
#  'E1',
#  'E2',
#  'E3',
#  'E4',
#  'E5',
#  'F1',
#  'F2',
#  'F3',
#  'F4',
#  'F5',
#  'G1',
#  'G2',
#  'G3',
#  'G4',
#  'G5']

# %%
sns.countplot(x='grade',data=df,hue='loan_status')
# Out:
# <Axes: xlabel='grade', ylabel='count'>

# %%
plt.figure(figsize=(12,4))
subgrade_order = sorted(df['sub_grade'].unique())
sns.countplot(x='sub_grade', data=df, order=subgrade_order, hue='sub_grade',
              palette='coolwarm', legend=False)
# Out:
# <Axes: xlabel='sub_grade', ylabel='count'>

# %%
plt.figure(figsize=(12,4))
subgrade_order = sorted(df['sub_grade'].unique())
sns.countplot(x='sub_grade',data=df,order = subgrade_order,palette='coolwarm' ,hue='loan_status')
# Out:
# <Axes: xlabel='sub_grade', ylabel='count'>

# %%
f_and_g = df[(df['grade']=='G') | (df['grade']=='F')]

plt.figure(figsize=(12,4))
subgrade_order = sorted(f_and_g['sub_grade'].unique())
sns.countplot(x='sub_grade',data=f_and_g,order = subgrade_order,hue='loan_status')
# Out:
# <Axes: xlabel='sub_grade', ylabel='count'>

# %%
df['loan_status'].unique()
# Out:
# array(['Fully Paid', 'Charged Off'], dtype=object)

# %%
df['loan_repaid'] = df['loan_status'].map({'Fully Paid':1,'Charged Off':0})

# %%
df[['loan_repaid','loan_status']]
# Out:
#         loan_repaid  loan_status
# 0                 1   Fully Paid
# 1                 1   Fully Paid
# 2                 1   Fully Paid
# 3                 1   Fully Paid
# 4                 0  Charged Off
# ...             ...          ...
# 396025            1   Fully Paid
# 396026            1   Fully Paid
# 396027            1   Fully Paid
# 396028            1   Fully Paid
# 396029            1   Fully Paid
#
# [396030 rows x 2 columns]

# %%
df_numeric = df.select_dtypes(include=['number'])
df_numeric.corr()['loan_repaid'].sort_values().drop('loan_repaid').plot(kind='bar')
# Out:
# <Axes: >

# %% [markdown]
# Data PreProcessing

# %%
df.head()
# Out:
#    loan_amnt        term  int_rate  installment grade sub_grade  \
# 0    10000.0   36 months     11.44       329.48     B        B4
# 1     8000.0   36 months     11.99       265.68     B        B5
# 2    15600.0   36 months     10.49       506.97     B        B3
# 3     7200.0   36 months      6.49       220.65     A        A2
# 4    24375.0   60 months     17.27       609.33     C        C5
#
#                  emp_title emp_length home_ownership  annual_inc  ... pub_rec  \
# 0                Marketing  10+ years           RENT    117000.0  ...     0.0
# 1          Credit analyst     4 years       MORTGAGE     65000.0  ...     0.0
# 2             Statistician   < 1 year           RENT     43057.0  ...     0.0
# 3          Client Advocate    6 years           RENT     54000.0  ...     0.0
# 4  Destiny Management Inc.    9 years       MORTGAGE     55000.0  ...     0.0
#
#   revol_bal revol_util total_acc initial_list_status  application_type  \
# ...

# %% [markdown]
# Missing Data

# %%
len(df)
# Out:
# 396030

# %%
df.isnull().sum()
# Out:
# loan_amnt                   0
# term                        0
# int_rate                    0
# installment                 0
# grade                       0
# sub_grade                   0
# emp_title               22927
# emp_length              18301
# home_ownership              0
# annual_inc                  0
# verification_status         0
# issue_d                     0
# loan_status                 0
# purpose                     0
# title                    1756
# dti                         0
# earliest_cr_line            0
# open_acc                    0
# pub_rec                     0
# revol_bal                   0
# revol_util                276
# total_acc                   0
# initial_list_status         0
# application_type            0
# mort_acc                37795
# pub_rec_bankruptcies      535
# address                     0
# loan_repaid                 0
# dtype: int64

# %%
100* df.isnull().sum()/len(df)
# Out:
# loan_amnt               0.000000
# term                    0.000000
# int_rate                0.000000
# installment             0.000000
# grade                   0.000000
# sub_grade               0.000000
# emp_title               5.789208
# emp_length              4.621115
# home_ownership          0.000000
# annual_inc              0.000000
# verification_status     0.000000
# issue_d                 0.000000
# loan_status             0.000000
# purpose                 0.000000
# title                   0.443401
# dti                     0.000000
# earliest_cr_line        0.000000
# open_acc                0.000000
# pub_rec                 0.000000
# revol_bal               0.000000
# revol_util              0.069692
# total_acc               0.000000
# initial_list_status     0.000000
# application_type        0.000000
# mort_acc                9.543469
# pub_rec_bankruptcies    0.135091
# address                 0.000000
# loan_repaid             0.000000
# dtype: float64

# %%
feat_info('emp_title')
print('\n')
feat_info('emp_length')
# Out:
# The job title supplied by the Borrower when applying for the loan.*
#
#
# Employment length in years. Possible values are between 0 and 10 where 0 means less than one year and 10 means ten or more years.

# %%
df['emp_title'].nunique()
# Out:
# 173105

# %%
df['emp_title'].value_counts()
# Out:
# emp_title
# Teacher                    4389
# Manager                    4250
# Registered Nurse           1856
# RN                         1846
# Supervisor                 1830
#                            ...
# Postman                       1
# McCarthy & Holthus, LLC       1
# jp flooring                   1
# Histology Technologist        1
# Gracon Services, Inc          1
# Name: count, Length: 173105, dtype: int64

# %%
df = df.drop('emp_title',axis=1)

# %%
sorted(df['emp_length'].dropna().unique())
# Out:
# ['1 year',
#  '10+ years',
#  '2 years',
#  '3 years',
#  '4 years',
#  '5 years',
#  '6 years',
#  '7 years',
#  '8 years',
#  '9 years',
#  '< 1 year']

# %%
emp_length_order = ['< 1 year', '1 year', '2 years', '3 years', '4 years', 
                    '5 years', '6 years', '7 years', '8 years', '9 years', 
                    '10+ years']

# %%
plt.figure(figsize=(12,4))
sns.countplot(x='emp_length', data=df, order=emp_length_order)
plt.xticks(rotation=45)
plt.show()

# %%
plt.figure(figsize=(12,4))
sns.countplot(x='emp_length',data=df,order=emp_length_order,hue='loan_status')
# Out:
# <Axes: xlabel='emp_length', ylabel='count'>

# %%
emp_co = df[df['loan_status']=="Charged Off"].groupby("emp_length").count()['loan_status']

# %%
emp_fp = df[df['loan_status']=="Fully Paid"].groupby("emp_length").count()['loan_status']

# %%
emp_len = emp_co/emp_fp

# %%
emp_len
# Out:
# emp_length
# 1 year       0.248649
# 10+ years    0.225770
# 2 years      0.239560
# 3 years      0.242593
# 4 years      0.238213
# 5 years      0.237911
# 6 years      0.233341
# 7 years      0.241887
# 8 years      0.249625
# 9 years      0.250735
# < 1 year     0.260830
# Name: loan_status, dtype: float64

# %%
emp_len.plot(kind='bar')
# Out:
# <Axes: xlabel='emp_length'>

# %%
df = df.drop('emp_length',axis=1)

# %%
df.isnull().sum()
# Out:
# loan_amnt                   0
# term                        0
# int_rate                    0
# installment                 0
# grade                       0
# sub_grade                   0
# home_ownership              0
# annual_inc                  0
# verification_status         0
# issue_d                     0
# loan_status                 0
# purpose                     0
# title                    1756
# dti                         0
# earliest_cr_line            0
# open_acc                    0
# pub_rec                     0
# revol_bal                   0
# revol_util                276
# total_acc                   0
# initial_list_status         0
# application_type            0
# mort_acc                37795
# pub_rec_bankruptcies      535
# address                     0
# loan_repaid                 0
# dtype: int64

# %%
df['purpose'].head(10)
# Out:
# 0              vacation
# 1    debt_consolidation
# 2           credit_card
# 3           credit_card
# 4           credit_card
# 5    debt_consolidation
# 6      home_improvement
# 7           credit_card
# 8    debt_consolidation
# 9    debt_consolidation
# Name: purpose, dtype: object

# %%
df['title'].head(10)
# Out:
# 0                   Vacation
# 1         Debt consolidation
# 2    Credit card refinancing
# 3    Credit card refinancing
# 4      Credit Card Refinance
# 5         Debt consolidation
# 6           Home improvement
# 7       No More Credit Cards
# 8         Debt consolidation
# 9         Debt Consolidation
# Name: title, dtype: object

# %%
df = df.drop('title',axis=1)

# %%
feat_info('mort_acc')
# Out:
# Number of mortgage accounts.

# %%
df['mort_acc'].value_counts()
# Out:
# mort_acc
# 0.0     139777
# 1.0      60416
# 2.0      49948
# 3.0      38049
# 4.0      27887
# 5.0      18194
# 6.0      11069
# 7.0       6052
# 8.0       3121
# 9.0       1656
# 10.0       865
# 11.0       479
# 12.0       264
# 13.0       146
# 14.0       107
# 15.0        61
# 16.0        37
# 17.0        22
# 18.0        18
# 19.0        15
# 20.0        13
# 24.0        10
# 22.0         7
# 21.0         4
# 25.0         4
# 27.0         3
# 32.0         2
# 31.0         2
# 23.0         2
# 26.0         2
# 28.0         1
# 30.0         1
# 34.0         1
# Name: count, dtype: int64

# %%
print("Correlation with the mort_acc column")
df_numeric = df.select_dtypes(include=['number'])
df_numeric.corr()['mort_acc'].sort_values()
# Out:
# Correlation with the mort_acc column
# int_rate               -0.082583
# dti                    -0.025439
# revol_util              0.007514
# pub_rec                 0.011552
# pub_rec_bankruptcies    0.027239
# loan_repaid             0.073111
# open_acc                0.109205
# installment             0.193694
# revol_bal               0.194925
# loan_amnt               0.222315
# annual_inc              0.236320
# total_acc               0.381072
# mort_acc                1.000000
# Name: mort_acc, dtype: float64

# %%
print("Mean of mort_acc column per total_acc")
df_numeric.groupby('total_acc').mean()['mort_acc']
# Out:
# Mean of mort_acc column per total_acc
# total_acc
# 2.0      0.000000
# 3.0      0.052023
# 4.0      0.066743
# 5.0      0.103289
# 6.0      0.151293
#            ...
# 124.0    1.000000
# 129.0    1.000000
# 135.0    3.000000
# 150.0    2.000000
# 151.0    0.000000
# Name: mort_acc, Length: 118, dtype: float64

# %%
total_acc_avg = df_numeric.groupby('total_acc').mean()['mort_acc']

# %%
total_acc_avg[2.0]
# Out:
# np.float64(0.0)

# %%
def fill_mort_acc(total_acc,mort_acc):
    '''
    Accepts the total_acc and mort_acc values for the row.
    Checks if the mort_acc is NaN , if so, it returns the avg mort_acc value
    for the corresponding total_acc value for that row.
    
    total_acc_avg here should be a Series or dictionary containing the mapping of the
    groupby averages of mort_acc per total_acc values.
    '''
    if np.isnan(mort_acc):
        return total_acc_avg[total_acc]
    else:
        return mort_acc

# %%
df['mort_acc'] = df.apply(lambda x: fill_mort_acc(x['total_acc'], x['mort_acc']), axis=1)

# %%
df.isnull().sum()
# Out:
# loan_amnt                 0
# term                      0
# int_rate                  0
# installment               0
# grade                     0
# sub_grade                 0
# home_ownership            0
# annual_inc                0
# verification_status       0
# issue_d                   0
# loan_status               0
# purpose                   0
# dti                       0
# earliest_cr_line          0
# open_acc                  0
# pub_rec                   0
# revol_bal                 0
# revol_util              276
# total_acc                 0
# initial_list_status       0
# application_type          0
# mort_acc                  0
# pub_rec_bankruptcies    535
# address                   0
# loan_repaid               0
# dtype: int64

# %%
df = df.dropna()

# %%
df.isnull().sum()
# Out:
# loan_amnt               0
# term                    0
# int_rate                0
# installment             0
# grade                   0
# sub_grade               0
# home_ownership          0
# annual_inc              0
# verification_status     0
# issue_d                 0
# loan_status             0
# purpose                 0
# dti                     0
# earliest_cr_line        0
# open_acc                0
# pub_rec                 0
# revol_bal               0
# revol_util              0
# total_acc               0
# initial_list_status     0
# application_type        0
# mort_acc                0
# pub_rec_bankruptcies    0
# address                 0
# loan_repaid             0
# dtype: int64

# %%
df.select_dtypes(['object']).columns
# Out:
# Index(['term', 'grade', 'sub_grade', 'home_ownership', 'verification_status',
#        'issue_d', 'loan_status', 'purpose', 'earliest_cr_line',
#        'initial_list_status', 'application_type', 'address'],
#       dtype='object')

# %%
df['term'].value_counts()
# Out:
# term
# 36 months    301247
# 60 months     93972
# Name: count, dtype: int64

# %%
df = df.drop('grade',axis=1)

# %%
subgrade_dummies = pd.get_dummies(df['sub_grade'],drop_first=True)

# %%
df = pd.concat([df.drop('sub_grade',axis=1),subgrade_dummies],axis=1)

# %%
df.columns
# Out:
# Index(['loan_amnt', 'term', 'int_rate', 'installment', 'home_ownership',
#        'annual_inc', 'verification_status', 'issue_d', 'loan_status',
#        'purpose', 'dti', 'earliest_cr_line', 'open_acc', 'pub_rec',
#        'revol_bal', 'revol_util', 'total_acc', 'initial_list_status',
#        'application_type', 'mort_acc', 'pub_rec_bankruptcies', 'address',
#        'loan_repaid', 'A2', 'A3', 'A4', 'A5', 'B1', 'B2', 'B3', 'B4', 'B5',
#        'C1', 'C2', 'C3', 'C4', 'C5', 'D1', 'D2', 'D3', 'D4', 'D5', 'E1', 'E2',
#        'E3', 'E4', 'E5', 'F1', 'F2', 'F3', 'F4', 'F5', 'G1', 'G2', 'G3', 'G4',
#        'G5'],
#       dtype='object')

# %%
df.select_dtypes(['object']).columns
# Out:
# Index(['term', 'home_ownership', 'verification_status', 'issue_d',
#        'loan_status', 'purpose', 'earliest_cr_line', 'initial_list_status',
#        'application_type', 'address'],
#       dtype='object')

# %%
dummies = pd.get_dummies(df[['verification_status', 'application_type','initial_list_status','purpose' ]],drop_first=True)
df = df.drop(['verification_status', 'application_type','initial_list_status','purpose'],axis=1)
df = pd.concat([df,dummies],axis=1)

# %%
df['home_ownership'].value_counts()
# Out:
# home_ownership
# MORTGAGE    198022
# RENT        159395
# OWN          37660
# OTHER          110
# NONE            29
# ANY              3
# Name: count, dtype: int64

# %%
df['home_ownership']=df['home_ownership'].replace(['NONE', 'ANY'], 'OTHER')

dummies = pd.get_dummies(df['home_ownership'],drop_first=True)
df = df.drop('home_ownership',axis=1)
df = pd.concat([df,dummies],axis=1)

# %%
df['zip_code'] = df['address'].apply(lambda address:address[-5:])

# %%
dummies = pd.get_dummies(df['zip_code'],drop_first=True)
df = df.drop(['zip_code','address'],axis=1)
df = pd.concat([df,dummies],axis=1)

# %%
df = df.drop('issue_d',axis=1)

# %%
df['earliest_cr_year'] = df['earliest_cr_line'].apply(lambda date:int(date[-4:]))
df = df.drop('earliest_cr_line',axis=1)

# %%
df.select_dtypes(['object']).columns
# Out:
# Index(['term', 'loan_status'], dtype='object')

# %% [markdown]
# ## Train Test Split

# %%
from sklearn.model_selection import train_test_split

# %%
df = df.drop('loan_status',axis=1)

# %%
X = df.drop('loan_repaid',axis=1).values
y = df['loan_repaid'].values
print(X)
# Out:
# [[10000.0 ' 36 months' 11.44 ... False False 1990]
#  [8000.0 ' 36 months' 11.99 ... False False 2004]
#  [15600.0 ' 36 months' 10.49 ... False False 2007]
#  ...
#  [5000.0 ' 36 months' 9.99 ... False False 1997]
#  [21000.0 ' 60 months' 15.31 ... False False 1990]
#  [2000.0 ' 36 months' 13.61 ... False False 1998]]

# %%
print(y)
# Out:
# [1 1 1 ... 1 1 1]

# %% [markdown]
# ## Grabbing a Sample for Training Time

# %%
X.shape
# Out:
# (395219, 78)

# %%
columns = ['loan_amnt', 'term', 'int_rate', 'emp_length', 'home_ownership', 
           'annual_inc', 'loan_status', 'issue_d', 'earliest_cr_line', 
           'revol_util', 'revol_bal', 'total_acc', 'mort_acc', 
           'pub_rec_bankruptcies', 'application_type', 'mortgage_year']

# %%
columns = df.drop('loan_repaid', axis=1).columns
X = pd.DataFrame(X, columns=columns)

# %%
print(X.shape[1])  # say it prints 25

# then make sure your list has exactly 25 column names
len(columns)
# Out:
# 78
# 78

# %%
X = pd.DataFrame(X)

# %%
X.columns = df.drop('loan_repaid', axis=1).columns  # if available

# %%
X['term'] = X['term'].str.extract('(\d+)').astype(float)

# %%
X.shape
# Out:
# (395219, 78)

# %%
X = pd.DataFrame(X, columns=df.drop('loan_repaid', axis=1).columns)

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.20, random_state=101)

# %%
from sklearn.preprocessing import MinMaxScaler

# %%
scaler = MinMaxScaler()

# %%
X_train = scaler.fit_transform(X_train)

# %%
X_test = scaler.transform(X_test)

# %% [markdown]
# ## Creating the Model

# %%
import tensorflow as tf
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Activation,Dropout
from tensorflow.keras.constraints import max_norm

# %%
model = Sequential()

# input layer
model.add(Dense(78,  activation='relu'))
model.add(Dropout(0.2))

# hidden layer
model.add(Dense(39, activation='relu'))
model.add(Dropout(0.2))

# hidden layer
model.add(Dense(19, activation='relu'))
model.add(Dropout(0.2))

# output layer
model.add(Dense(units=1,activation='sigmoid'))

# Compile model
model.compile(loss='binary_crossentropy', optimizer='adam')

# %%
model.fit(x=X_train, 
          y=y_train, 
          epochs=25,
          batch_size=256,
          validation_data=(X_test, y_test), 
          )
# Out:
# Epoch 1/25
# 1236/1236 ━━━━━━━━━━━━━━━━━━━━ 2s 1ms/step - loss: 0.3012 - val_loss: 0.2646
# Epoch 2/25
# 1236/1236 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 0.2657 - val_loss: 0.2633
# Epoch 3/25
# 1236/1236 ━━━━━━━━━━━━━━━━━━━━ 1s 957us/step - loss: 0.2633 - val_loss: 0.2625
# Epoch 4/25
# 1236/1236 ━━━━━━━━━━━━━━━━━━━━ 1s 949us/step - loss: 0.2621 - val_loss: 0.2629
# Epoch 5/25
# 1236/1236 ━━━━━━━━━━━━━━━━━━━━ 1s 975us/step - loss: 0.2611 - val_loss: 0.2637
# Epoch 6/25
# 1236/1236 ━━━━━━━━━━━━━━━━━━━━ 1s 954us/step - loss: 0.2606 - val_loss: 0.2615
# Epoch 7/25
# 1236/1236 ━━━━━━━━━━━━━━━━━━━━ 1s 987us/step - loss: 0.2601 - val_loss: 0.2615
# Epoch 8/25
# 1236/1236 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 0.2595 - val_loss: 0.2614
# Epoch 9/25
# 1236/1236 ━━━━━━━━━━━━━━━━━━━━ 1s 952us/step - loss: 0.2595 - val_loss: 0.2612
# Epoch 10/25
# 1236/1236 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 0.2589 - val_loss: 0.2614
# Epoch 11/25
# ...

# %%
from tensorflow.keras.models import load_model

# %%
from keras.saving import save_model
save_model(model, 'full_data_project_model.h5.keras')

# %%
losses = pd.DataFrame(model.history.history)

# %%
losses[['loss','val_loss']].plot()
# Out:
# <Axes: >

# %%
from sklearn.metrics import classification_report,confusion_matrix

# %%
predictions = (model.predict(X_test) > 0.5).astype("int32")
# Out:
# 2471/2471 ━━━━━━━━━━━━━━━━━━━━ 1s 223us/step

# %%
print(classification_report(y_test,predictions))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.98      0.44      0.61     15658
#            1       0.88      1.00      0.93     63386
#
#     accuracy                           0.89     79044
#    macro avg       0.93      0.72      0.77     79044
# weighted avg       0.90      0.89      0.87     79044

# %%
confusion_matrix(y_test,predictions)
# Out:
# array([[ 6848,  8810],
#        [  122, 63264]])

# %%
import random
random.seed(101)
random_ind = random.randint(0,len(df))

new_customer = df.drop('loan_repaid',axis=1).iloc[random_ind]
new_customer
# Out:
# loan_amnt                                  24000.0
# term                                     60 months
# int_rate                                     13.11
# installment                                 547.43
# grade                                            B
# sub_grade                                       B4
# emp_length                               10+ years
# home_ownership                            MORTGAGE
# annual_inc                                 85000.0
# verification_status                Source Verified
# issue_d                                   Jan-2013
# loan_status                             Fully Paid
# purpose                                credit_card
# title                                         Debt
# dti                                          10.98
# earliest_cr_line                          Oct-1991
# open_acc                                       6.0
# pub_rec                                        0.0
# ...

# %%
new_customer.dtypes
# Out:
# dtype('O')

# %%
print(new_customer.head())
# Out:
# loan_amnt         24000.0
# term            60 months
# int_rate            13.11
# installment        547.43
# grade                   B
# Name: 304691, dtype: object

# %%
feature_names = X.columns  # save this before transforming
X_train = scaler.fit_transform(X)

# %%
new_customer_encoded = pd.get_dummies(new_customer)
new_customer_encoded = new_customer_encoded.reindex(columns=feature_names, fill_value=0)
new_customer_scaled = scaler.transform(new_customer_encoded)
pred = (model.predict(new_customer_scaled) > 0.5).astype("int32")
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step

# %%
pred = (model.predict(new_customer_scaled) > 0.5).astype("int32")
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step

# %% [raw]
# print(pred)

# %%
df.iloc[random_ind]['loan_repaid']
# Out:
# np.int64(1)
